# %%
# Import Numpy & PyTorch
import numpy as np
import torch

# %% [markdown]
# ## Linear Regression Model using PyTorch built-ins
#
# Let's re-implement the same model using some built-in functions and classes from PyTorch.
#
# And now using two different targets: Apples and Oranges

# %%
# Imports
import torch.nn as nn

# %%
# Input (temp, rainfall, humidity)
inputs = np.array([[73, 67, 43], [91, 88, 64], [87, 134, 58], [102, 43, 37], [69, 96, 70], [73, 67, 43], [91, 88, 64], [87, 134, 58], [102, 43, 37], [69, 96, 70], [73, 67, 43], [91, 88, 64], [87, 134, 58], [102, 43, 37], [69, 96, 70]], dtype='float32')
# Targets (apples, oranges)
targets = np.array([[56, 70], [81, 101], [119, 133], [22, 37], [103, 119], 
                    [56, 70], [81, 101], [119, 133], [22, 37], [103, 119], 
                    [56, 70], [81, 101], [119, 133], [22, 37], [103, 119]], dtype='float32')

# %%
inputs = torch.from_numpy(inputs)
targets = torch.from_numpy(targets)

# %% [markdown]
# ### Dataset and DataLoader
#
# We'll create a `TensorDataset`, which allows access to rows from `inputs` and `targets` as tuples. We'll also create a DataLoader, to split the data into batches while training. It also provides other utilities like shuffling and sampling.

# %%
# Import tensor dataset & data loader
from torch.utils.data import TensorDataset, DataLoader

# %%
# Define dataset
dataset = TensorDataset(inputs, targets)
dataset[0:3]
# Out:
# (tensor([[ 73.,  67.,  43.],
#          [ 91.,  88.,  64.],
#          [ 87., 134.,  58.]]),
#  tensor([[ 56.,  70.],
#          [ 81., 101.],
#          [119., 133.]]))

# %%
# Define data loader
batch_size = 5
DL = DataLoader(dataset, batch_size, shuffle=True)
next(iter(DL))
# Out:
# [tensor([[ 87., 134.,  58.],
#          [ 69.,  96.,  70.],
#          [ 91.,  88.,  64.],
#          [ 69.,  96.,  70.],
#          [ 87., 134.,  58.]]),
#  tensor([[119., 133.],
#          [103., 119.],
#          [ 81., 101.],
#          [103., 119.],
#          [119., 133.]])]

# %% [markdown]
# ### nn.Linear
# Instead of initializing the weights & biases manually, we can define the model using `nn.Linear`.

# %%
# Define model
final_model = nn.Linear(3, 2)
print(final_model.weight, end="\n---------\n")
print(final_model.bias)
# Out:
# Parameter containing:
# tensor([[ 0.4416,  0.4059,  0.0424],
#         [-0.0894,  0.1715,  0.1043]], requires_grad=True)
# ---------
# Parameter containing:
# tensor([0.1327, 0.1561], requires_grad=True)

# %% [markdown]
# ### Optimizer
# Instead of manually manipulating the weights & biases using gradients, we can use the optimizer `optim.SGD`.

# %%
# Define optimizer
opt = torch.optim.SGD(final_model.parameters(), lr=1e-5)

# %% [markdown]
# ### Loss Function
# Instead of defining a loss function manually, we can use the built-in loss function `mse_loss`.

# %%
# Import nn.functional
import torch.nn.functional as F

# %%
# Define loss function
loss_fn = F.mse_loss

# %%
loss = loss_fn(final_model(inputs) , targets)
print(loss)
# Out:
# tensor(3846.6377, grad_fn=<MseLossBackward>)

# %% [markdown]
# ### Train the model
#
# We are ready to train the model now. We can define a utility function `fit` which trains the model for a given number of epochs.

# %%
# Define a utility function to train the model
def fit(num_epochs, final_model, loss_fn, opt):
    for epoch in range(num_epochs):
        for xb,yb in DL:
            # Generate predictions
            pred = final_model(xb)
            loss = loss_fn(pred,yb)
            # Perform gradient descent
            loss.backward()
            opt.step()
            opt.zero_grad()
    print('Training loss: ', loss_fn(final_model(inputs), targets))

# %%
# Train the model for 100 epochs
fit(100 , final_model , loss_fn, opt)
# Out:
# Training loss:  tensor(27.6048, grad_fn=<MseLossBackward>)

# %%
# Generate predictions
preds = final_model(inputs)
preds
# Out:
# tensor([[ 58.8044,  71.4664],
#         [ 80.0889,  98.4561],
#         [121.6386, 136.5159],
#         [ 29.5528,  42.9833],
#         [ 93.2624, 111.8068],
#         [ 58.8044,  71.4664],
#         [ 80.0889,  98.4561],
#         [121.6386, 136.5159],
#         [ 29.5528,  42.9833],
#         [ 93.2624, 111.8068],
#         [ 58.8044,  71.4664],
#         [ 80.0889,  98.4561],
#         [121.6386, 136.5159],
#         [ 29.5528,  42.9833],
#         [ 93.2624, 111.8068]], grad_fn=<AddmmBackward>)

# %%
# Compare with targets
targets
# Out:
# tensor([[ 56.,  70.],
#         [ 81., 101.],
#         [119., 133.],
#         [ 22.,  37.],
#         [103., 119.],
#         [ 56.,  70.],
#         [ 81., 101.],
#         [119., 133.],
#         [ 22.,  37.],
#         [103., 119.],
#         [ 56.,  70.],
#         [ 81., 101.],
#         [119., 133.],
#         [ 22.,  37.],
#         [103., 119.]])

# %% [markdown]
# Now we can define the model, optimizer and loss function exactly as before.

# %%
fit(100 , final_model , loss_fn, opt)
# Out:
# Training loss:  tensor(10.8845, grad_fn=<MseLossBackward>)

# %% [markdown]
# ## Exercise 1:
#  Try Linear Regression just using numpy (Without Tensorflow/Pytorch or other torch library). You can optionally use sklearn (if you want)
#
#
# ## Exercise 2:
#  Try Linear regression on same prediction data using Tensorflow

# %%
# Input (temp, rainfall, humidity)
inputs = np.array([[73, 67, 43], [91, 88, 64], [87, 134, 58], [102, 43, 37], [69, 96, 70], [73, 67, 43], [91, 88, 64], [87, 134, 58], [102, 43, 37], [69, 96, 70], [73, 67, 43], [91, 88, 64], [87, 134, 58], [102, 43, 37], [69, 96, 70]], dtype='float32')
# Targets (apples, oranges)
targets = np.array([[56, 70], [81, 101], [119, 133], [22, 37], [103, 119], 
                    [56, 70], [81, 101], [119, 133], [22, 37], [103, 119], 
                    [56, 70], [81, 101], [119, 133], [22, 37], [103, 119]], dtype='float32')

x_shape = inputs.shape

# %%
# weights and biases
weights = np.random.rand(2,3)
biases = np.random.rand(15,2)
print("Weights:",weights,sep='\n')
print("Biases:",biases,sep="\n")
# Out:
# Weights:
# [[0.41970279 0.78532619 0.93294688]
#  [0.83573311 0.433827   0.14905229]]
# Biases:
# [[0.70845441 0.52082129]
#  [0.84195522 0.31862377]
#  [0.15415494 0.61109687]
#  [0.4957217  0.15773629]
#  [0.32063107 0.79426015]
#  [0.92184713 0.71767821]
#  [0.95728005 0.47185972]
#  [0.63272862 0.3574304 ]
#  [0.81339681 0.79630477]
#  [0.0419184  0.10458519]
#  [0.25765503 0.9967419 ]
#  [0.28821398 0.49931683]
#  [0.82086009 0.24516014]
#  [0.82972478 0.53853765]
#  [0.60760557 0.33400323]]

# %%
# Define the model
def model(x):
    return x @ np.transpose(weights) + biases

# %%
# Generate predictions
preds = model(inputs)

# %%
# Compare with targets
print("Predictions : ", preds, sep="\n")
print("Targets : ",targets, sep="\n")
# Out:
# Predictions :
# [[124.08032921  97.00499605]
#  [167.85221487 124.08645965]
#  [196.01292704 140.0977287 ]
#  [111.59346762 109.57200953]
#  [169.97772006 110.5408973 ]
#  [124.29372193  97.20185297]
#  [167.96753969 124.2396956 ]
#  [196.49150072 139.84406223]
#  [111.91114273 110.21057801]
#  [169.69900738 109.85122234]
#  [123.62952984  97.48091666]
#  [167.29847363 124.26715272]
#  [196.67963219 139.73179197]
#  [111.92747071 109.95281089]
#  [170.26469455 110.08064038]]
# Targets :
# [[ 56.  70.]
#  [ 81. 101.]
#  [119. 133.]
#  [ 22.  37.]
#  [103. 119.]
#  [ 56.  70.]
#  [ 81. 101.]
#  [119. 133.]
#  [ 22.  37.]
#  [103. 119.]
#  [ 56.  70.]
#  [ 81. 101.]
#  [119. 133.]
#  [ 22.  37.]
#  [103. 119.]]

# %%
# MSE loss
def mse(t1, t2):
    diff = t1 - t2
    return np.sum(diff * diff) / len(diff)

# %%
# Compute loss
loss = mse(preds, targets)
print(loss)
# Out:
# 7481.260172524849

# %%
# compute gradients
biases_grad = (preds-targets)*2/x_shape[0]
weights_grad = (np.matmul(np.transpose((preds-targets)),inputs))*2/x_shape[0]

print("weights_grad:",weights_grad, sep="\n")
print("biases_grad:",biases_grad, sep="\n")
# Out:
# weights_grad:
# [[13348.00850388 13139.63520504  8389.50434703]
#  [ 4610.05742843  2830.20781404  2053.58885146]]
# biases_grad:
# [[ 9.07737723  3.60066614]
#  [11.58029532  3.07819462]
#  [10.26839027  0.94636383]
#  [11.94579568  9.67626794]
#  [ 8.93036267 -1.12788036]
#  [ 9.10582959  3.62691373]
#  [11.59567196  3.09862608]
#  [10.3322001   0.91254163]
#  [11.98815236  9.7614104 ]
#  [ 8.89320098 -1.21983702]
#  [ 9.01727064  3.66412222]
#  [11.50646315  3.10228703]
#  [10.35728429  0.89757226]
#  [11.99032943  9.72704145]
#  [ 8.96862594 -1.18924795]]

# %% [markdown]
# Adjust weights

# %%
# Adjust weights
weights -= weights_grad * 1e-5
biases -= biases_grad * 1e-5

# %%
print("Weights:",weights,sep='\n')
print("Biases:",biases,sep="\n")
# Out:
# Weights:
# [[0.28622271 0.65392984 0.84905184]
#  [0.78963254 0.40552492 0.1285164 ]]
# Biases:
# [[0.70836364 0.52078528]
#  [0.84183942 0.31859299]
#  [0.15405225 0.61108741]
#  [0.49560224 0.15763952]
#  [0.32054177 0.79427143]
#  [0.92175607 0.71764194]
#  [0.95716409 0.47182873]
#  [0.6326253  0.35742127]
#  [0.81327692 0.79620715]
#  [0.04182947 0.10459739]
#  [0.25756486 0.99670526]
#  [0.28809892 0.49928581]
#  [0.82075652 0.24515116]
#  [0.82960488 0.53844038]
#  [0.60751588 0.33401512]]

# %%
# Calculate loss
preds = model(inputs)
loss = mse(preds, targets)
print(loss)
# Out:
# 3743.7825314073216

# %%
# repeating same for 200 times
for i in range(200):
    preds = model(inputs)
    loss = mse(preds, targets)
    
    biases_grad = ((((inputs@np.transpose(weights))+biases)-targets))*2/x_shape[0]
    weights_grad = (np.matmul(np.transpose((((inputs@np.transpose(weights))+biases)-targets)),inputs))*2/x_shape[0]

    weights -= weights_grad * 1e-5
    biases -= biases_grad * 1e-5

# %%
# Calculate loss
preds = model(inputs)
loss = mse(preds, targets)
print(loss)
# Out:
# 36.97693214837389

# %%
# Print predictions
print(preds)
# Out:
# [[ 57.7190085   71.56681167]
#  [ 83.03563318  97.20434449]
#  [116.34098616 138.64012526]
#  [ 22.90033148  42.89252614]
#  [101.64857018 110.1806437 ]
#  [ 57.93234404  71.76361583]
#  [ 83.1509271   97.35753938]
#  [116.8194316  138.38652675]
#  [ 23.21792147  43.5309235 ]
#  [101.36993219 109.49115355]
#  [ 57.26832992  72.04260475]
#  [ 82.48204032  97.38498913]
#  [117.00751266 138.27428658]
#  [ 23.23424506  43.27322545]
#  [101.93546778 109.72051011]]

# %%
# Print targets
print(targets)
# Out:
# [[ 56.  70.]
#  [ 81. 101.]
#  [119. 133.]
#  [ 22.  37.]
#  [103. 119.]
#  [ 56.  70.]
#  [ 81. 101.]
#  [119. 133.]
#  [ 22.  37.]
#  [103. 119.]
#  [ 56.  70.]
#  [ 81. 101.]
#  [119. 133.]
#  [ 22.  37.]
#  [103. 119.]]
