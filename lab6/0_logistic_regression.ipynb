# %%
#Importing libraries
import numpy as np 
import pandas as pd 
import io
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('BuyComputer.csv')

data.drop(columns=['User ID',],axis=1,inplace=True)
data.head()
# Out:
#    Age  EstimatedSalary  Purchased
# 0   19            19000          0
# 1   35            20000          0
# 2   26            43000          0
# 3   27            57000          0
# 4   19            76000          0

# %%
#Declare label as last column in the source file
label = data.iloc[:,-1].values

# %%
#Declaring X as all columns excluding last
X = data.iloc[:,:-1].values

# %%
# Splitting data
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, label, test_size = 0.30, random_state = 98)

# %%
# Sacaling data
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
#Variabes to calculate sigmoid function
y_pred = []
len_x = len(X_train[0])
w = []
b = 0.2
print(len_x)
# Out:
# 2

# %%
entries = len(X_train[:,0])
entries
# Out:
# 280

# %%
for weights in range(len_x):
    w.append(0)
w
# Out:
# [0, 0]

# %%
# Sigmoid function
def sigmoid(z):
  return (1 / (1 + np.exp(-z)))

# %%
def predict(inputs):
    z = np.dot(w,inputs) + b
    temp = sigmoid(z)
    return temp

# %%
#Loss function
def loss_func(y,a):
    J = -(y * np.log(a) + (1-y) * np.log(1-a))
    return J

# %%
dw = []
db = 0
J = 0
alpha = 0.1
for x in range(len_x):
    dw.append(0)

# %%
#Repeating the process 3000 times
for iterations in range(3000):
    for i in range(entries):
        localx = X_train[i]
        a = predict(localx)   
        dz = a - y_train[i]
        J += loss_func(y_train[i],a)

        for j in range(len_x):
            dw[j] = dw[j] + (localx[j] * dz)

        db += dz
    J = J / entries
    db = db / entries

    for x in range(len_x):
        dw[x] = dw[x] / entries

    for x in range(len_x):
        w[x] = w[x] - (alpha * dw[x])
    b = b - (alpha * db)         
    J=0

# %%
#Print weight
w
# Out:
# [2.35117338333747, 1.0965756429447582]

# %%
#print bias
b
# Out:
# -1.3145309111211565

# %%
#predicting the label
for x in range(len(y_test)):
    y_pred.append(predict(X_test[x]))

# %%
#print actual and predicted values in a table
print("Actual\t\tPredicted")
for x in range(len(y_pred)):
    print(y_test[x] ,y_pred[x], sep="\t\t")
    if y_pred[x]>=0.5:
        y_pred[x]=1
    else:
        y_pred[x]=0
# Out:
# Actual		Predicted
# 1		0.3819296049402871
# 0		0.01558402534760582
# 0		0.02608205892966156
# 0		0.08227021031905088
# 0		0.4129080059457102
# 1		0.5311990646272695
# 0		0.31271536461397553
# 1		0.9497093961287416
# 1		0.33242649379283895
# 0		0.05902128256561082
# 1		0.5293581907818571
# 1		0.9660634735933082
# 1		0.683622169437691
# 1		0.34284191043070295
# 1		0.3312826756391289
# 0		0.15227321872211882
# 0		0.02780721146549513
# 1		0.5632513078949155
# 1		0.8799437679022482
# 0		0.9690553225800552
# 0		0.128415835345805
# 0		0.008089870786293106
# 0		0.26409409296396524
# 0		0.4111175727584119
# 0		0.017570910660707137
# 0		0.5931690055269079
# 0		0.28109504919900136
# 0		0.3440051081214747
# 1		0.15094616414210507
# 0		0.1454368828484329
# 1		0.9865195906554248
# 0		0.05356552390800995
# 1		0.6089503355291648
# 0		0.14243002973895913
# 0		0.1482142271504902
# 1		0.5619818652554505
# 1		0.9752549094699944
# 1		0.9195555744722317
# 1		0.9219263753249927
# 0		0.006596700757299399
# 1		0.8829601272577641
# 0		0.03927386004795926
# 0		0.005160585398108824
# 0		0.017030407056882337
# 1		0.4883614899293013
# 0		0.023476206045618182
# 0		0.25612379985342837
# 0		0.005800600008465693
# 0		0.02169767649630482
# 0		0.020095021933251352
# 0		0.7014048929838217
# 0		0.00293988947446967
# 1		0.1767294057114637
# 0		0.0989827764001966
# 0		0.340677230882226
# 1		0.2632274638434818
# 0		0.10480033573192575
# 1		0.7598761197747049
# 1		0.2632274638434818
# 0		0.003581868663324774
# 1		0.9864600981316585
# 1		0.7084820407173245
# 0		0.028679765292964607
# 1		0.8796342339277731
# 0		0.37897165000360467
# 0		0.06695364307230797
# 0		0.37897165000360467
# 0		0.03567503642830467
# 0		0.004819381262187975
# 1		0.9964022583453646
# 0		0.35679585137556685
# 1		0.872737430212261
# 0		0.008089870786293106
# 0		0.005469403618690221
# 0		0.0053145993271233654
# 1		0.9427588690592484
# 1		0.9394834305219748
# 0		0.022221783652960826
# 1		0.25796142559513124
# 0		0.006793281838620387
# 0		0.22871823357706458
# 1		0.9873761248443277
# 1		0.7881648653294815
# 1		0.4859574475738207
# 1		0.98381476567387
# 1		0.5944132947169132
# 0		0.16196620151790553
# 0		0.03891239342744767
# 0		0.03022196588767528
# 1		0.3836757427053036
# 1		0.9887030066352054
# 0		0.14728361070069476
# 1		0.9861911698268021
# 0		0.02760810975610828
# 0		0.008635513268682553
# 1		0.47874966178795847
# 0		0.011632304228346992
# 0		0.19798461673637407
# 0		0.0014446187884229235
# 1		0.4756188833961217
# 1		0.9550362488858307
# 0		0.4111175727584119
# 0		0.18808110662884245
# 0		0.09159288558281274
# 0		0.13947519600865171
# 1		0.940192988868298
# 0		0.12091581474146891
# 0		0.011413110689832846
# 1		0.9910227188037178
# 0		0.944061665786424
# 0		0.030373526497038842
# 0		0.1707838629926068
# 1		0.6872902732493665
# 0		0.01550508266038592
# 1		0.8594529993378406
# 1		0.9934996296053098
# 0		0.008288066212103547
# 1		0.7340366637213755
# 0		0.4129080059457102
# 0		0.07351470910457968

# %%
# Calculating accuracy of prediction
count = 0
for x in range(len(y_pred)):
    if(y_pred[x] == y_test[x]):
        count += 1

print('Accuracy:',(count / (len(y_pred))) * 100)
# Out:
# Accuracy: 85.0

# %% [markdown]
# ## Using sklearn LogisticRegression model##

# %%
# Fitting Logistic Regression to the Training set
from sklearn.linear_model import LogisticRegression
LR = LogisticRegression(random_state = 98) # roll no 98
#Fit
LR.fit(X_train,y_train)

#predicting the test label with LR. Predict always takes X as input
y_predict = LR.predict(X_test)

from sklearn.metrics import accuracy_score
print('Accuracy:', accuracy_score(y_predict,y_test))
# Out:
# Accuracy: 0.85

# %% [markdown]
# **Exercise:**
#
# Try logistic regression on BuyComputer dataset and set Random state=Your_RollNumber (last 3 digit of ID, incase if you don't have ID)
